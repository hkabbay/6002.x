# %% [markdown]
# <a href="https://colab.research.google.com/github/harryk1/6002.x/blob/master/XNOR_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create dataset
import pandas as pd
import numpy as np
input = np.array([[0,0] ,[0,1] ,[1,0] ,[1,1]])
target = np.array([[1], [0], [0], [1]])
df = pd.DataFrame(input, columns=['x', 'y'])
df['x XNOR y'] = target
df
# Out:
#    x  y  x XNOR y
# 0  0  0         1
# 1  0  1         0
# 2  1  0         0
# 3  1  1         1

# %%
# Import required libraries
from keras import models
from keras import layers

# %%
# Build model
network = models.Sequential()
network.add(layers.Dense(2, activation='relu', input_dim=2))
# network.add(layers.Dense(3, activation='relu'))
network.add(layers.Dense(1, activation='sigmoid'))
network.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['binary_accuracy'])

# %%
network.fit(input, target, epochs=3000)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6486 - binary_accuracy: 1.0000
# Epoch 502/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6485 - binary_accuracy: 1.0000
# Epoch 503/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6483 - binary_accuracy: 1.0000
# Epoch 504/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6482 - binary_accuracy: 1.0000
# Epoch 505/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6481 - binary_accuracy: 1.0000
# Epoch 506/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6480 - binary_accuracy: 1.0000
# Epoch 507/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6478 - binary_accuracy: 1.0000
# Epoch 508/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6477 - binary_accuracy: 1.0000
# Epoch 509/3000
# ...

# %%
scores = network.evaluate(input, target)
print("\n%s: %.2f%%" % (network.metrics_names[1], scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 302ms/step - loss: 0.3636 - binary_accuracy: 0.7500
#
# binary_accuracy: 75.00%

# %%
print (network.predict(input).round())
print ("weights", network.layers[0].get_weights()[0])
print ("biases", network.layers[0].get_weights()[1])
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [1.]]
# weights [[ 0.8479739 -1.5242611]
#  [ 1.4876083  1.5234098]]
# biases [-8.5056299e-01 -1.6230954e-04]
